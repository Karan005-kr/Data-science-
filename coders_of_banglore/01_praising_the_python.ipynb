# %%
with open("final.txt", encoding='utf-8') as f:
    data = f.read()

# %%
chunks = data.split("\n\n") 
chunks = [c for c in chunks if len(c)>3]

# %%
chunks[0]
# Out:
# 'techie_koramangala\n420 posts\n9,800 followers\n310 following\nArjun M.\nSoftware Engineer\n💻 Full-stack @ SaaS startup\n☕ Working from cafes in Koramangala\ngithub.com/arjunmakes'

# %%
def parse_chunk(chunk):
    chunk = chunk.strip()
    sep_chunk = chunk.split('\n')
    username = sep_chunk[0]
    
    no_of_posts = int(sep_chunk[1].split("post")[0].replace(",",""))
    
    no_of_follower = float(sep_chunk[2].split("follower")[0].replace(",","").replace("K", "").replace("M", ""))
    
    if("K" in sep_chunk[2]):
        no_of_follower = int(no_of_follower * 1000)
    elif("M" in sep_chunk[2]):
        no_of_follower = int(no_of_follower * 1000000)
    else:
         no_of_follower = int(no_of_follower)

    
    no_of_following = float(sep_chunk[3].split("following")[0].replace(",","").replace("K", "").replace("M", ""))
    if("K" in sep_chunk[3]):
        no_of_following = int(no_of_following * 1000)
    elif("M" in sep_chunk[3]):
        no_of_following = int(no_of_following * 1000000)
    else:
        no_of_following = int(no_of_following)
    
    name = sep_chunk[4]
    if(len(sep_chunk)>5):
        type_of_page = sep_chunk[5]
        bio = "\n".join(sep_chunk[6:])

    else:
        type_of_page = "unknown"
        bio = ""
        # print(username, no_of_posts, no_of_following, no_of_follower, name, type_of_page, bio, sep="\n")
    return{"username": username, "no_of_posts": no_of_posts, "no_of_following": no_of_following, "no_of_follower": no_of_follower, "name": name, "type_of_page": type_of_page, "bio": bio}
# parse_chunk(chunks[0])

# %%
all_chunks = []
for chunk in chunks:
    parsed_chunk = parse_chunk(chunk)
    all_chunks.append(parsed_chunk)
print(all_chunks)
# Out:
# [{'username': 'techie_koramangala', 'no_of_posts': 420, 'no_of_following': 310, 'no_of_follower': 9800, 'name': 'Arjun M.', 'type_of_page': 'Software Engineer', 'bio': '💻 Full-stack @ SaaS startup\n☕ Working from cafes in Koramangala\ngithub.com/arjunmakes'}, {'username': 'blrcoder_girl', 'no_of_posts': 150, 'no_of_following': 120, 'no_of_follower': 6300, 'name': 'Riya Codes', 'type_of_page': 'Tech Creator', 'bio': '👩\u200d💻 Python | ML | Roadmaps\n🎥 Coding Reels + Daily Motivation\nlinktr.ee/riyacodes'}, {'username': 'hsr_startup_stories', 'no_of_posts': 980, 'no_of_following': 95, 'no_of_follower': 22400, 'name': 'Startup Stories HSR', 'type_of_page': 'Media', 'bio': '🚀 Interviews with Bangalore founders\n🎙️ Weekly startup breakdowns\nhsrstartupstories.com'}, {'username': 'cloud_dev_blr', 'no_of_posts': 210, 'no_of_following': 60, 'no_of_follower': 4500, 'name': 'Naveen DevOps', 'type_of_page': 'Engineer', 'bio': '☁️ AWS | Docker | K8s\n📍 Sarjapur\ngithub.com/naveencloud'}, {'username': 'koramangala_coffee_lover', 'no_of_posts': 300, 'no_of_following': 180, 'no_of_follower': 7900, 'name': 'Sana B.', 'type_of_page': 'Cafe Explorer', 'bio': '☕ Reviewing Bangalore’s hidden coffee spots\n📍 Koramangala\nyoutube.com/@sanacafehunter'}, {'username': 'ai_bangalore_news', 'no_of_posts': 1340, 'no_of_following': 200, 'no_of_follower': 38000, 'name': 'AI Bangalore', 'type_of_page': 'Media', 'bio': '🤖 Daily AI news from India\n📢 Startup & research updates\naibanglore.ai/news'}, {'username': 'techfounder_india', 'no_of_posts': 210, 'no_of_following': 450, 'no_of_follower': 19000, 'name': 'Dev Patel', 'type_of_page': 'Founder', 'bio': '⚡ Building SaaS in Fintech\n📍 Indiranagar\ndevpatel.io'}, {'username': 'coder_on_orr', 'no_of_posts': 65, 'no_of_following': 70, 'no_of_follower': 1900, 'name': 'Sriram', 'type_of_page': 'Backend Developer', 'bio': '🐍 Python | FastAPI enthusiast\n🌧️ Surviving ORR traffic\ngithub.com/sriramworks'}, {'username': 'blrdatascience_daily', 'no_of_posts': 540, 'no_of_following': 150, 'no_of_follower': 15100, 'name': 'Bangalore DS Daily', 'type_of_page': 'Media', 'bio': '📊 Data + AI + ML\n👩\u200d🏫 Tutorials | Job alerts\nblrdatascience.in'}, {'username': 'frontend_with_megha', 'no_of_posts': 175, 'no_of_following': 95, 'no_of_follower': 8200, 'name': 'Megha Gupta', 'type_of_page': 'Frontend Dev', 'bio': '🎨 React | Next.js | UI Tips\n🌸 Bengaluru\nmeghacodes.dev'}, {'username': 'cubbonpark_runner', 'no_of_posts': 95, 'no_of_following': 40, 'no_of_follower': 1500, 'name': 'Aman', 'type_of_page': 'Lifestyle', 'bio': '🏃 Running after coding\n📍 Cubbon Park\nstrava.com/amanrunning'}, {'username': 'indiranagar_food_maps', 'no_of_posts': 600, 'no_of_following': 155, 'no_of_follower': 12300, 'name': 'Food Maps BLR', 'type_of_page': 'Food & Drink', 'bio': '🍜 Maps of best places around Indiranagar\n📍 Bangalore\nfoodmapsblr.com'}, {'username': 'python_blr_jobs', 'no_of_posts': 1200, 'no_of_following': 18, 'no_of_follower': 21000, 'name': 'Python Jobs BLR', 'type_of_page': 'Community', 'bio': '💼 Python/ML/AI jobs daily\n📍 Bengaluru\npythonblr.jobs'}, {'username': 'sarjapur_coder', 'no_of_posts': 143, 'no_of_following': 52, 'no_of_follower': 3200, 'name': 'Roshan', 'type_of_page': 'Full-stack Dev', 'bio': '🧑\u200d💻 MERN | DevTools\nCurrently debugging from Sarjapur\nroshancodes.dev'}, {'username': 'open_source_blr', 'no_of_posts': 300, 'no_of_following': 78, 'no_of_follower': 9100, 'name': 'BLR Open Source', 'type_of_page': 'Community', 'bio': '🌐 Meetups | Talks | OSS\ngithub.com/blropensource'}, {'username': 'techwalk_blr', 'no_of_posts': 430, 'no_of_following': 320, 'no_of_follower': 11000, 'name': 'Tech Walk Bangalore', 'type_of_page': 'Media', 'bio': '🚶 Exploring tech parks & cafes\n📍 Ecoworld | Manyata | Bagmane\ntechwalkblr.com'}, {'username': 'itpl_daily', 'no_of_posts': 590, 'no_of_following': 210, 'no_of_follower': 14200, 'name': 'ITPL Daily', 'type_of_page': 'Blog', 'bio': '🏢 Inside Whitefield Tech Life\n🚌 Bus stand stor ...

# %%
import json
s = json.dumps(all_chunks, indent=4)
with open("data.json", "w") as f:
    f.write(s)

# %% [markdown]
# # who has the maximum post?
#
# lets write the code to find max posts

# %%
max = 0
for chunk in all_chunks:
    if(max<chunk['no_of_posts']):
        max = chunk['no_of_posts']
        chunk_with_max_post = chunk
print(chunk_with_max_post['username'])
# Out:
# startuphub_blr

# %% [markdown]
# # who has maximum followers?
#
# lets write the code to find max followers

# %%
maxx = 0
for chunk in all_chunks:
    if(maxx<chunk['no_of_follower']):
        maxx = chunk['no_of_follower']
        chunk_with_maxx_follower = chunk
print(chunk_with_maxx_follower['username'])
# Out:
# _anujsinghal

# %% [markdown]
# # Who follows the maximum people?
#
# lets write the code to find people follows the maximum people

# %%
pemax = 0
for chunk in all_chunks:
    if(pemax<chunk['no_of_following']):
        pemax = chunk['no_of_following']
        chunk_with_pemax_following = chunk
print(chunk_with_pemax_following['username'])
# Out:
# bangalore_tech_bro

# %% [markdown]
# # how many categories
#
# lets write the code to find the number of categories

# %%
categories = set()
for chunk in all_chunks:
    categories.add(chunk['type_of_page'])
print(f"There are {len(categories)} categories")
# Out:
# There are 34 categories
