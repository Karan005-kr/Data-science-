# %%
import numpy as np

arr = np.array([1,2,3,4,5])

print(arr.dtype)
# Out:
# int64

# %%
arr.astype('float64')
# Out:
# array([1., 2., 3., 4., 5.])

# %%
arr2 = np.array([1,2,3,4,5], dtype='float32')

# %%
arr2
# Out:
# array([1., 2., 3., 4., 5.], dtype=float32)

# %%
arr.nbytes
# Out:
# 40

# %%
arr2.nbytes
# Out:
# 20
