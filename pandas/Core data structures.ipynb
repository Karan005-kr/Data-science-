# %%
import pandas as pd

# %%
s = pd.Series([43,23,65,68,27,78,87])

# %%
type(s)
# Out:
# pandas.core.series.Series

# %%
s
# Out:
# 0    43
# 1    23
# 2    65
# 3    68
# 4    27
# 5    78
# 6    87
# dtype: int64

# %%
s1 = pd.Series([43,23,65,68,27,78,87], index = ["kirti", "kunal","keshav","komal","krish","kushal","karan"])

# %%
s1
# Out:
# kirti     43
# kunal     23
# keshav    65
# komal     68
# krish     27
# kushal    78
# karan     87
# dtype: int64

# %%
data = {
    "name" : ['alice' , 'bob' , 'charlie'],
    "age" : [25, 30, 35],
    "city" : ['delhi', 'mumbai' , 'bangalore']
}

df = pd.DataFrame(data)
df
# Out:
#       name  age       city
# 0    alice   25      delhi
# 1      bob   30     mumbai
# 2  charlie   35  bangalore

# %%
df.index
# Out:
# RangeIndex(start=0, stop=3, step=1)

# %%
df.columns
# Out:
# Index(['name', 'age', 'city'], dtype='object')
